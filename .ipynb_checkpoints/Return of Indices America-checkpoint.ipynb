# %% [markdown]
# ## Calculating the Return of Indices

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# Consider three famous American market indices – Dow Jones, S&P 500, and the Nasdaq for the period of 1st of January 2000 until today.

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^DJI', '^GSPC', '^IXIC']

ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source='yahoo', start='2000-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                     ^DJI        ^GSPC        ^IXIC
# Date
# 2000-01-03  11357.509766  1455.219971  4131.149902
# 2000-01-04  10997.929688  1399.420044  3901.689941
# 2000-01-05  11122.650391  1402.109985  3877.540039
# 2000-01-06  11253.259766  1403.449951  3727.129883
# 2000-01-07  11522.559570  1441.469971  3882.620117

# %%
ind_data.tail()
# Out:
#                     ^DJI        ^GSPC        ^IXIC
# Date
# 2019-05-24  25585.689453  2826.060059  7637.009766
# 2019-05-28  25347.769531  2802.389893  7607.350098
# 2019-05-29  25126.410156  2783.020020  7547.310059
# 2019-05-30  25169.880859  2788.860107  7567.720215
# 2019-05-31  24815.039062  2752.060059  7453.148438

# %% [markdown]
# Normalize the data to 100 and plot the results on a graph.

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize=(15, 6));
plt.show()

# %% [markdown]
# How would you explain the common and the different parts of the behavior of the three indices?

# %% [markdown]
# *****

# %% [markdown]
# Obtain the simple returns of the indices.

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1

ind_returns.tail()
# Out:
#                 ^DJI     ^GSPC     ^IXIC
# Date
# 2019-05-24  0.003735  0.001354  0.001144
# 2019-05-28 -0.009299 -0.008376 -0.003884
# 2019-05-29 -0.008733 -0.006912 -0.007892
# 2019-05-30  0.001730  0.002098  0.002704
# 2019-05-31 -0.014098 -0.013195 -0.015140

# %% [markdown]
# Estimate the average annual return of each index.

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^DJI     0.058006
# ^GSPC    0.050986
# ^IXIC    0.061657
# dtype: float64

# %%
# new stuff i tried for indicator

# %%
tickers = ['PG', '^GSPC', '^DJI']

data_2 = pd.DataFrame()

for t in tickers:
    data_2[t] = wb.DataReader(t, data_source = 'yahoo', start = '2007-1-1') ['Adj Close']

# %%
data_2.tail()
# Out:
#                     PG        ^GSPC          ^DJI
# Date
# 2019-05-24  106.690002  2826.060059  25585.689453
# 2019-05-28  104.459999  2802.389893  25347.769531
# 2019-05-29  104.190002  2783.020020  25126.410156
# 2019-05-30  105.330002  2788.860107  25169.880859
# 2019-05-31  102.910004  2752.060059  24815.039062

# %%
(data_2 / data_2.iloc[0] * 100).plot(figsize=(15,6));
plt.show()
