# %% [markdown]
# ## Simple Returns - Part II

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# $$
# \frac{P_1 - P_0}{P_0} = \frac{P_1}{P_0} - 1
# $$

# %%
import numpy as np
from pandas_datareader import data as wb
MSFT = wb.DataReader('MSFT', data_source='iex', start='2015-1-1')
MSFT['simple_return'] = (MSFT['close'] / MSFT['close'].shift(1)) - 1
print (MSFT['simple_return'])
# Out:
# date
# 2015-01-02         NaN
# 2015-01-05   -0.009304
# 2015-01-06   -0.014572
# 2015-01-07    0.012705
# 2015-01-08    0.029419
# 2015-01-09   -0.008405
# 2015-01-12   -0.012504
# 2015-01-13   -0.005257
# 2015-01-14   -0.008628
# 2015-01-15   -0.010336
# 2015-01-16    0.016711
# 2015-01-20    0.003242
# 2015-01-21   -0.010129
# 2015-01-22    0.026350
# 2015-01-23    0.001061
# 2015-01-26   -0.003604
# 2015-01-27   -0.092534
# 2015-01-28   -0.034458
# 2015-01-29    0.019907
# 2015-01-30   -0.038323
# 2015-02-02    0.021783
# 2015-02-03    0.007751
# 2015-02-04    0.005769
# 2015-02-05    0.014579
# 2015-02-06   -0.000941
# 2015-02-09   -0.001179
# 2015-02-10    0.005665
# 2015-02-11   -0.005163
# 2015-02-12    0.016753
# 2015-02-13    0.018100
#                 ...
# 2019-04-18    0.013140
# 2019-04-22    0.003162
# 2019-04-23    0.013575
# 2019-04-24   -0.003428
# 2019-04-25    0.033117
# 2019-04-26    0.005730
# 2019-04-29   -0.000924
# 2019-04-30    0.006396
# 2019-05-01   -0.020826
# 2019-05-02   -0.013060
# 2019-05-03    0.021314
# 2019-05-06   -0.005818
# 2019-05-07   -0.020523
# 2019-05-08   -0.000080
# 2019-05-09   -0.000079
# 2019-05-10    0.012987
# 2019-05-13   -0.029733
# 2019-05-14    0.011188
# 2019-05-15    0.014082
# 2019-05-16    0.023092
# 2019-05-17   -0.006670
# 2019-05-20   -0.014445
# 2019-05-21    0.005387
# 2019-05-22    0.006068
# 2019-05-23   -0.011671
# 2019-05-24    0.000476
# 2019-05-28   -0.000634
# 2019-05-29   -0.009670
# 2019-05-30    0.006323
# 2019-05-31   -0.016305
# Name: simple_return, Length: 1110, dtype: float64

# %% [markdown]
# Plot the simple returns on a graph.

# %%
import matplotlib.pyplot as plt

# %%
# figsize is going to change how many on X and Y

# %%
MSFT['simple_return'].plot(figsize=(8, 5))
plt.show()

# %% [markdown]
# Calculate the average daily return.

# %%
avg_returns_d = MSFT['simple_return'].mean()
avg_returns_d
# Out:
# 0.0010809986926435923

# %% [markdown]
# Estimate the average annual return. 250 trading days

# %%
avg_returns_a = MSFT['simple_return'].mean() * 250
avg_returns_a
# Out:
# 0.2702496731608981

# %% [markdown]
# Print the percentage version of the result as a float with 2 digits after the decimal point.

# %%
print (str(round(avg_returns_a, 4) * 100) + ' %')
# Out:
# 27.02 %
